# %% [markdown]
# <a href="https://colab.research.google.com/github/daria-nishchenko/B4U_Workshops/blob/main/Nishchenko_B4U_Workshop1_Lab6_hands_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab 6 Assignment: Producing Publication-Ready Figures**
# ---
# #**Лабораторна робота 6: Створення фігур для наукових публікацій **

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Instructions**
# ---
# ##**Інструкції**

# %% [markdown]
# In your own Google Colab, use the commands presented in the previous sections to create the following graphs using the 'titanic' example dataset included with Seaborn. You will be graded based on whether your Colab notebook can produce graphs identical or near-identical to the five plots at the end of this assignment.
#
# Notes:
#
# *   The position of your plots' legends may be different.
# *   While not required by this assignment, remember you can export your plots using Matplotlib's *savefig()* function with *bbox_inches='tight'*.
#
# To start this assignment, return to the commands you used to produce the plots in Lab 2. Your plots should looks as follows:
#
# ---
#
# У вашому власному Google Colab використовуйте команди, наведені в попередніх блоках, щоб створити наведені нижче графіки, використовуючи дані "titanic", що входить до Seaborn. Ви отримаєте оцінку залежно від того, чи зможе ваш блокнот Colab створювати графіки, ідентичні або майже ідентичні п’яти графікам у кінці цього завдання.
#
# Примітки:
#
# * Розташування легенд ваших графів може відрізнятися.
# * Хоча завдання цього не вимагає, пам’ятайте, що ви можете експортувати свої графіки за допомогою функції *savefig()* Matplotlib з параметром *bbox_inches='tight'*.
#
# Щоб розпочати це завдання, поверніться до команд, які ви використовували для створення графіків у попередній лабораторній роботі. Ваші графіки мають виглядати наступним чином:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, let's use what we learned this lab to improve these three graphs.
# **To start, rerun the following commmands we used last lab to modify the 'titanic' dataset.**
#
# ---
#
# Тепер давайте використаємо те, що ви вивчили сьогодні, щоб покращити ці три графіки.
# **Для початку повторно запустіть наступні команди, які ми використовували в минулій лабораторній роботі, щоб змінити набір даних «titanic».**

# %%
lab3_data = sns.load_dataset('titanic')
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'
lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1,  'survived_str'] = 'yes'

# %%
lab3_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# **Next, set the style of the plots you will make here to '*white*' and the context to '*paper*' using the following:**
# ---
# **Далі встановіть стиль графів, які ви створюватимете, на «*white*», а контекст на «*paper*», використовуючи наступне:**

# %%
sns.set_style("white")
sns.set_context("paper")

# %% [markdown]
# **Then, to maintain a consistant color-scheme, save the following Python dictionary under a name of your choice:**
# ---
# **Потім, для того щоб мати однотипну колірну схему у всіх графах, збережіть наступний словник Python під назвою на ваш вибір:**

# %%
colors={'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}

# %% [markdown]
# # **Plot #1**
# ---
#
# Граф №1

# %% [markdown]
# Remaking your bar plot with the new color scheme should produce this, give-or-take the position of the legend:
# ---
# Переробка вашого коробчатого графіку з новою кольоровою схемою повинна призвести до такого розташування легенди:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# Notice how both male categories are blue while both female categories are orange.
#
# Зверніть увагу, що обидві чоловічі категорії сині, а жіночі - помаранчеві.

# %%
# Create the bar plot with error bars
ax = sns.barplot(data=lab3_data, x='pclass', y='survived', hue='who', errorbar=('ci', 90), capsize=0.05, palette=colors)

# Define the new labels
current_labels = [tick.get_text() for tick in ax.get_xticklabels()]
new_labels = ['First Class', 'Second Class', 'Third Class']
ax.set_xticklabels(new_labels)

# Set the x-label
plt.xlabel('class')

plt.show()
# Out:
# <ipython-input-6-d80b6a01fc07>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels)

# %% [markdown]
# Next, to better contrast between the richest and poorest individuals on the Titanic, let's remove the 'Second' class category by using a custom x-axis order.
#
# Your graph should now look similar to this:
#
# ---
#
# Далі, щоб краще передати різницю між найбагатшими та найбіднішими особами на Титаніку, давайте видалимо категорію «Другий» клас, використовуючи спеціальний порядок осі х.
#
# Тепер ваш графік має виглядати приблизно так:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define the new labels and custom x-axis order
new_labels = ['First Class', 'Third Class']
x_order = [1, 3]  # Corresponding order for the labels

# Create the bar plot with error bars and custom x-axis order
ax = sns.barplot(data=lab3_data, x='pclass', y='survived', hue='who', errorbar=('ci', 90), capsize=0.05, palette=colors, order=x_order)

# Set the x-axis tick labels
ax.set_xticklabels(new_labels)

# Set the x-label
plt.xlabel('class')

plt.show()
# Out:
# <ipython-input-7-8fe6078c3047>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels)

# %% [markdown]
# **Let's now set the plot's xlabel to 'Boarding Class' and ylabel to 'Mean survival 'rate'.**
#
# *Hint*: Your code should look something like this pseudocode here:
#
# ---
#
# **Тепер давайте встановимо xlabel графіка на «Boarding Class», а ylabel на «Mean survival 'rate».**
#
# *Підказка*: Ваш код має виглядати приблизно так, як цей псевдокод:

# %% [markdown]
# ```
# axes=barplot(*args)
# axes.set(*args)
# ```
#
# **This is not real code, only what your code should generally look like**

# %%
# Define the new labels and custom x-axis order
new_labels = ['First Class', 'Third Class']
x_order = [1, 3]  # Corresponding order for the labels

# Create the bar plot with error bars and custom x-axis order
ax = sns.barplot(data=lab3_data, x='pclass', y='survived', hue='who', errorbar=('ci', 90), capsize=0.05, palette=colors, order=x_order)

# Set the x-axis tick labels
ax.set_xticklabels(new_labels)

# Set the x-label
plt.xlabel('Boarding Class')
plt.ylabel('Mean survival rate')

plt.show()
# Out:
# <ipython-input-8-fa8bb0f5f698>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels)

# %% [markdown]
# Once you've gotten it right, running your new code should produce a plot like this:
# ---
# Після того, як ви все зробили правильно, запуск вашого коду має згенерувати такий графік:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Finally, despine your plot with the command below:**
# ---
# **Нарешті, приберемо рамку графіку за допомогою команди нижче:**

# %%
sns.despine()

# %% [markdown]
# Your finished plot should now look approximately like this:
# ---
# Тепер ваш графік сюжет має виглядати приблизно так:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define the new labels and custom x-axis order
new_labels = ['First Class', 'Third Class']
x_order = [1, 3]  # Corresponding order for the labels

# Create the bar plot with error bars and custom x-axis order
ax = sns.barplot(data=lab3_data, x='pclass', y='survived', hue='who', errorbar=('ci', 90), capsize=0.05, palette=colors, order=x_order)

# Set the x-axis tick labels
ax.set_xticklabels(new_labels)

# Set the label
plt.xlabel('Boarding Class')
plt.ylabel('Mean survival rate')

sns.despine()
plt.show()
# Out:
# <ipython-input-10-2f4597c8f579>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels)

# %% [markdown]
# With the first of the five plots down, let's move onto the next.
#
# Отримавши перший із п’яти графіків, перейдемо до наступного.

# %% [markdown]
# ###Plot #2
# ---
# ###Графік №2

# %% [markdown]
# For this one, we will be combining the Box Plot and Strip Plot you produced in the previous lab.
#
# **To start, produce a colorless version of your previous boxplot as follows:**
#
# ---
#
# Для цього ми об’єднаємо діаграму коробкову та категорійну точкову діаграми, створені в попередній лабораторній роботі.
#
# **Для початку створіть безбарвну версію вашого попереднього коробкового графіка таким чином:**

# %% [markdown]
# ![download.png](attachment:237b8c14-ed12-4cb7-bcab-dc8215b7aea7.png)![image.png](data:image/png;base64,...)

# %%
default_palette = sns.color_palette()

# Create the box plot
sns.boxplot(data=lab3_data, x='survived_str', y='age', hue='who', fliersize=0, boxprops={'edgecolor':'black','facecolor':(1,1,1,0)})

# Set the x-label
plt.xlabel('survived')

plt.show()

# %% [markdown]
# **Next, graph your old Strip Plot using the new color-scheme.**
# ---
# **Далі побудуйте вашу попередню категорійну точкову діаграму, використовуючи нову палітру.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create the strip plot
sns.stripplot(data=lab3_data, x='survived_str', y='age', hue='who', jitter=.3, alpha=.6, dodge=True, palette=colors)

# Set the x-label
plt.xlabel('survived')

plt.show()

# %% [markdown]
# **Then, name both of these plots 'axes2' and run the following code:**
# ---
# **Потім назвіть обидва ці графіки «axes2» і запустіть такий код:**

# %%
#name both of these plots 'axes2'
axes2 = sns.boxplot(data=lab3_data, x='survived_str', y='age', hue='who', fliersize=0, boxprops={'edgecolor':'black','facecolor':(1,1,1,0)})
axes2 = sns.stripplot(data=lab3_data, x='survived_str', y='age', hue='who', jitter=.3, alpha=.6, dodge=True, palette=colors)

#following code
handles, labels = axes2.get_legend_handles_labels()
plt.legend(handles[4:8], labels[4:8], title='who')

# %% [markdown]
# Combined, your plots should turn into this:
# ---
# У сукупності гарфіки сюжети повинні перетворитися у наступне:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Finally, finish the graph by performing the following:
# *   Pass the *zorder=0* argument to *sns.stripplot*.
# *   Pass the *zorder=5* argument to *sns.boxplot*.
# *   Set the *xlabel* to 'Survived' and *ylabel* to 'Age'.
# *   Add the command *sns.despine()*.
#
#
# Notice that now the lines of the boxplot are drawn on top of the datapoints instead of underneath them.
#
# ---
#
# Нарешті завершіть графік, виконавши такі дії:
# * Передайте аргумент *zorder=0* до *sns.stripplot*.
# * Передайте аргумент *zorder=5* до *sns.boxplot*.
# * Установіть *xlabel* на «Survived» і *ylabel* на «Age».
# * Додайте команду *sns.despine()*.
#
#
# Зверніть увагу, що тепер лінії прямокутної діаграми малюються поверх точок даних, а не під ними.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create the plot 'axes2'
axes2 = sns.boxplot(data=lab3_data, x='survived_str', y='age', hue='who', fliersize=0, boxprops={'edgecolor':'black','facecolor':(1, 1,1,0)}, zorder=5)
axes2 = sns.stripplot(data=lab3_data, x='survived_str', y='age', hue='who', jitter=.3, alpha=.6, dodge=True, palette=colors, zorder=0)
handles, labels = axes2.get_legend_handles_labels()
plt.legend(handles[4:8], labels[4:8], title='who')

# Set the label
plt.xlabel('Survived')
plt.ylabel('Age')

sns.despine()
plt.show()

# %% [markdown]
# ###Plot #3
# ---
# ###Графік №3

# %% [markdown]
# The third plot to graph will be the violin plot representation of Plot #2.
# Its specifications are near-identical to Plot #2:
#
# *  Color datapoints by the 'who' they represent demographically.
# *  Set the *xlabel* to 'Survived' and *ylabel* to 'Age'.
# *  Add the command *sns.despine()*.
#
# ---
#
# Третім графіком буде скрипковий граф даних з завдання 2.
# Його характеристики майже ідентичні до другого графіку цього завдання:
#
# * Розфарбуйте точки даних за тим, кого вони представляють демографічно.
# * Установіть *xlabel* на «Survived» і *ylabel* на «Age».
# * Додайте команду *sns.despine()*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create the violin plot
sns.violinplot(data=lab3_data, x='survived_str', y='age', hue='who', palette=colors)

# Set the label
plt.xlabel('Survived')
plt.ylabel('Age')

sns.despine()
plt.show()

# %% [markdown]
# ###Plot #4
# ---
# ###Графік №4

# %% [markdown]
# So far the plots you've made are improvements of those from the previous lab. For the remaining two graphs, however, we will once again investigate the passengers of the Titanic, this time with more visualization methods in our toolkit.
#
# To start, let's make a scatter plot displaying 'age' vs. 'fare'. This will provide some insight into how much different groups of passengers paid in 1912 to board what would become a tragic cruise.
#
# The specifications for this graph are as follows:
# *  Color datapoints by the 'class' of the individual.
# *  Set the *xlabel* to 'Age' and *ylabel* to 'Fare'.
# *  Despine the plot.
#
# Following this, your scatter plot should look as follows:
#
# ---
#
#
# Наразі створені вами графіки є покращенням графіків із попередньої лабораторної. Проте для решти графіків, ми знову досліджуватимемо пасажирів Титаніку, цього разу додатковими методами візуалізації.
#
# Для початку створимо точкову діаграму, що відображатиме «age»(вік) проти «fare»(тариф). Це надасть нам уявлення про те, скільки різні групи пасажирів платили в 1912 році, щоб сісти на борт, що став для них трагічним.
#
# Специфікації для цього графіку наступні:
# * Колір точки даних за «класом» особи.
# * Установіть *xlabel* на «Age» і *ylabel* на «Fare».
# * Виконайте команду despine.
#
# Після цього ваша точкова діаграма має виглядати наступним чином:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From this, we can see that the variation in what First Class passengeres paid appears much greater than variation within the Second Class and Third Class groups.
#
# Additionally, we can see two outlier individuals in their thirties who paid around £500 for their fare. According to [this website](https://www.in2013dollars.com/uk/inflation/1912?amount=500) plus Google's currency converter, this would be around $73,000 today.
#
# ---
#
# З цього ми бачимо, що вартість квитка першого класу варіювала сильніше, ніж другого та третього класу.
#
# Крім того, ми бачимо двох осіб у віці за тридцять, які заплатили близько 500 фунтів стерлінгів за проїзд. За даними [цього веб-сайту](https://www.in2013dollars.com/uk/inflation/1912?amount=500) і конвертером валют Google, сьогодні це буде приблизно 73 000 доларів США.

# %%
# Create the scatter plot
sns.scatterplot(data=lab3_data, x='age', y='fare', hue='class')

# Set the label
plt.xlabel('Age')
plt.ylabel('Fare')

sns.despine()
plt.show()

# %% [markdown]
# ###Plot #5
# ---
# ###Графік №5

# %% [markdown]
# While the scatter plot gave us a general idea what passengers of different ages and boarding classes paid, it was unable to provide us much more demographic-specific information beyond that.
#
# While we could make a box+strip plot or violin plot for each combination of boy/girl/man/woman and first/second/third classes, the resulting graph would probably look very busy.
#
# So instead, let's make use a heatmap. **We can start by running the following code:**
#
# As you copy-paste it, try and follow what the commands do based on what you learned during the first lecture on DataFrame manipulation with Pandas.
#
# ---
#
# Точкова діаграма дала нам загальне уявлення про те, що платять пасажири різного віку та класів посадки, але вона не змогла надати нам більше інформації щодо демографічних показників.
#
# Ми могли б створити діаграму «коробка+категорійна точкова» або «скрипка» для кожної комбінації хлопчик/дівчинка/чоловік/жінка та перший/другий/третій класи, отриманий графік, швидше за все виглядатиме дуже насиченим(перегруженим).
#
# Замість цього давайте скористаємося тепловою картою. **Ми можемо почати із запуску наступного коду:**
#
# Копіюючи та вставляючи його, спробуйте простежити за тим, що роблять команди на основі того, що ви дізналися під час першої лекції про маніпуляції DataFrame за допомогою Pandas.

# %%
lab3_data_subset=lab3_data[['class','who','fare']]
lab3_data_subset=lab3_data_subset.dropna(how='any')
lab3_data_subsetAverage=lab3_data_subset.groupby(['class','who']).mean()
lab3_data_subsetAverage=lab3_data_subsetAverage.reset_index()
lab3_data_subsetAverage.head()
# Out:
# <ipython-input-17-29a8c999ea1d>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   lab3_data_subsetAverage=lab3_data_subset.groupby(['class','who']).mean()
#     class    who        fare
# 0   First    boy  117.802767
# 1   First   girl  160.962500
# 2   First    man   65.951086
# 3   First  woman  104.317995
# 4  Second    boy   27.306022

# %% [markdown]
# **Next, convert this categorical data into matrix data as was shown in the tutorial. The new DataFrame containing the matrix data should be named 'matrix_data'. Once completed, run the following code to plot the heatmap.**
# ---
# **Далі перетворіть ці категоричні дані в матричні дані, як показано в підручнику. Новий DataFrame, що містить дані матриці, повинен мати назву 'matrix_data'. Після завершення запустіть наступний код, щоб побудувати теплову карту.**

# %%
matrix_data = lab3_data_subsetAverage.pivot(index='class', columns='who', values='fare')
matrix_data.head()
# Out:
# who            boy        girl        man       woman
# class
# First   117.802767  160.962500  65.951086  104.317995
# Second   27.306022   29.240000  19.054124   20.868624
# Third    27.716371   19.023753  11.340213   15.354351

# %%
axes5 = sns.heatmap(data=matrix_data, annot=True,fmt='.2f',cmap='coolwarm')
for text in axes5.texts: text.set_text('£' + text.get_text())
axes5.set(xlabel='Demographic', ylabel='Boarding Class', xticklabels=['boy','girl','man','woman'])
# Out:
# [Text(0.5, 22.71666666666666, 'Demographic'),
#  Text(49.91666666666667, 0.5, 'Boarding Class'),
#  [Text(0.5, 0, 'boy'),
#   Text(1.5, 0, 'girl'),
#   Text(2.5, 0, 'man'),
#   Text(3.5, 0, 'woman')]]

# %% [markdown]
# As we did with the scatter plot, we can see that Second Class and Third Class passengers generally paid around the same amount while individuals in First Class had relatively higher variation in their fares. However, with the heatmap we can now clearly see that within the First Class, girls paid the highest average fare while First Class men paid the least.
#
# Furthermore, we can obtain numerical values for each category directly from the plot itself. This lends itself well toward converting fares from pound sterling in 1912 to their modern-day value.
#
# Finally with this heatmap made, you have completed Lab Assignment 3 and produced five publication-ready plots. Congratulations！
#
# For your reference, the plots you will be graded upon are listed below.
#
# ---
#
# У попередньому графіку ми побачили, що пасажири другого та третього класу зазвичай платили приблизно однакову суму, тоді як пасажири першого класу мали відносно більшу різницю в тарифах. Однак на тепловій карті ми тепер чітко бачимо, що в першому класі дівчата платили найвищий середній тариф, тоді як чоловіки першого класу платили найменше.
#
# Крім того, ми можемо отримати числові значення для кожної категорії безпосередньо з самої ділянки. Це добре підходить для конвертації тарифів із фунтів стерлінгів у 1912 році на їхню сучасну вартість.
#
# Нарешті, створивши цю теплову карту, ви виконали Лабораторне завдання і створили п’ять готових для публікації графіків. вітаю!
#
# Для довідки, графіки, за якими ви будете оцінюватися, перераховані нижче.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Finally with this heatmap made, you have completed Lab Assignment 3 and produced five publication-ready plots. Congratulations！
#
# For your reference, the plots you will be graded upon are listed below.
#
# ---
#
# Нарешті, створивши цю теплову карту, ви виконали Лабораторне завдання і створили п’ять готових для публікації графіків. вітаю!
#
# Для довідки, графіки, за якими ви будете оцінюватися, перераховані нижче.

# %% [markdown]
# ###Deliverables
# ---
# ###Результати

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
